# %% [markdown]
# Importação das bibliotecas e base de dados

# %%
import pandas as pd
import numpy as np
import plotly.express as px

# %%
dataset = pd.read_csv('../1-Visualização de dados Financeiros/criptos.csv')

# %%
dataset.shape
# Out:
# (869, 9)

# %%
dataset
# Out:
#            Date      MANA  POLKADOT   CARDANO      TRON     RIPLE      SAND  \
# 0    2020-01-01  0.031483       NaN  0.033458  0.013250  0.192667       NaN
# 1    2020-01-02  0.032639       NaN  0.032751  0.012870  0.188043       NaN
# 2    2020-01-03  0.032805       NaN  0.034180  0.013435  0.193521       NaN
# 3    2020-01-04  0.035837       NaN  0.034595  0.013521  0.194355       NaN
# 4    2020-01-05  0.036459       NaN  0.034721  0.013623  0.195537       NaN
# ..          ...       ...       ...       ...       ...       ...       ...
# 864  2022-05-14  1.326140       NaN  0.539358  0.072501  0.427774  1.432852
# 865  2022-05-15  1.330976       NaN  0.597500  0.072358  0.447371  1.448660
# 866  2022-05-16  1.172838       NaN  0.556716  0.069088  0.422499  1.314255
# 867  2022-05-17  1.213923       NaN  0.578077  0.072293  0.437623  1.371631
# 868  2022-05-18  1.039548  9.524648  0.506569  0.071071  0.406661  1.193646
#
#       POLYGON       BITCOIN
# 0    0.014962   7200.174316
# 1    0.014651   6985.470215
# 2    0.015194   7344.884277
# 3    0.014961   7410.656738
# 4    0.014914   7411.317383
# ..        ...           ...
# 864  0.686139  30101.265625
# 865  0.737566  31305.113281
# 866  0.677282  29862.917969
# 867  0.726942  30425.857422
# 868  0.628314  28762.384766
#
# [869 rows x 9 columns]

# %% [markdown]
# Taxa de retorno simples

# %%
len(dataset)
# Out:
# 869

# %%
dataset['BITCOIN'][0], dataset['BITCOIN'][len(dataset)-1]
# Out:
# (7200.17431640625, 28762.384765625)

# %%
((dataset['MANA'][len(dataset)-1] - dataset['MANA'][0]) / dataset['MANA'][0])*100
# Out:
# 3201.9346827586724

# %%
((dataset['POLKADOT'][len(dataset)-1] - dataset['POLKADOT'][0]) / dataset['POLKADOT'][0])*100
# Out:
# nan

# %%
((dataset['CARDANO'][len(dataset)-1] - dataset['CARDANO'][0]) / dataset['CARDANO'][0])*100
# Out:
# 1414.0453517208482

# %%
((dataset['TRON'][len(dataset)-1] - dataset['TRON'][0]) / dataset['TRON'][0])*100
# Out:
# 436.3870967469853

# %%
((dataset['RIPLE'][len(dataset)-1] - dataset['RIPLE'][0]) / dataset['RIPLE'][0])*100
# Out:
# 111.06953746052493

# %%
((dataset['SAND'][len(dataset)-1] - dataset['SAND'][0]) / dataset['SAND'][0])*100
# Out:
# nan

# %%
((dataset['BITCOIN'][len(dataset)-1] - dataset['BITCOIN'][0]) / dataset['BITCOIN'][0])*100
# Out:
# 299.46789482703633

# %%
(dataset['BITCOIN'][len(dataset)-1] / dataset['BITCOIN'][0]-1)*100 #maneira alternativa de fazer o mesmo cálculo
# Out:
# 299.46789482703633

# %%
dataset['BITCOIN']
# Out:
# 0       7200.174316
# 1       6985.470215
# 2       7344.884277
# 3       7410.656738
# 4       7411.317383
#            ...
# 864    30101.265625
# 865    31305.113281
# 866    29862.917969
# 867    30425.857422
# 868    28762.384766
# Name: BITCOIN, Length: 869, dtype: float64

# %%
dataset['BITCOIN'].shift(1) #O comando "shift" zera os valores sitados e desloca uma lista de númeor abaixo
# Out:
# 0               NaN
# 1       7200.174316
# 2       6985.470215
# 3       7344.884277
# 4       7410.656738
#            ...
# 864    29283.103516
# 865    30101.265625
# 866    31305.113281
# 867    29862.917969
# 868    30425.857422
# Name: BITCOIN, Length: 869, dtype: float64

# %%
dataset['RS BITCOIN']= (dataset['BITCOIN'] / dataset['BITCOIN'].shift(1))-1 #calculo da taxa DIÁRIA de retorno simples

# %%
dataset
# Out:
#            Date      MANA  POLKADOT   CARDANO      TRON     RIPLE      SAND  \
# 0    2020-01-01  0.031483       NaN  0.033458  0.013250  0.192667       NaN
# 1    2020-01-02  0.032639       NaN  0.032751  0.012870  0.188043       NaN
# 2    2020-01-03  0.032805       NaN  0.034180  0.013435  0.193521       NaN
# 3    2020-01-04  0.035837       NaN  0.034595  0.013521  0.194355       NaN
# 4    2020-01-05  0.036459       NaN  0.034721  0.013623  0.195537       NaN
# ..          ...       ...       ...       ...       ...       ...       ...
# 864  2022-05-14  1.326140       NaN  0.539358  0.072501  0.427774  1.432852
# 865  2022-05-15  1.330976       NaN  0.597500  0.072358  0.447371  1.448660
# 866  2022-05-16  1.172838       NaN  0.556716  0.069088  0.422499  1.314255
# 867  2022-05-17  1.213923       NaN  0.578077  0.072293  0.437623  1.371631
# 868  2022-05-18  1.039548  9.524648  0.506569  0.071071  0.406661  1.193646
#
#       POLYGON       BITCOIN  RS BITCOIN
# 0    0.014962   7200.174316         NaN
# 1    0.014651   6985.470215   -0.029819
# 2    0.015194   7344.884277    0.051452
# 3    0.014961   7410.656738    0.008955
# 4    0.014914   7411.317383    0.000089
# ..        ...           ...         ...
# 864  0.686139  30101.265625    0.027940
# 865  0.737566  31305.113281    0.039993
# 866  0.677282  29862.917969   -0.046069
# 867  0.726942  30425.857422    0.018851
# 868  0.628314  28762.384766   -0.054673
#
# [869 rows x 10 columns]

# %%
dataset['RS BITCOIN'].plot(); #Gráfico de taxas de retorno diário

# %%
dataset['RS BITCOIN'].mean()
# Out:
# 0.0023896588152187035

# %%
dataset.head(365) #busca os primeiros 365 registros
# Out:
#            Date      MANA  POLKADOT   CARDANO      TRON     RIPLE      SAND  \
# 0    2020-01-01  0.031483       NaN  0.033458  0.013250  0.192667       NaN
# 1    2020-01-02  0.032639       NaN  0.032751  0.012870  0.188043       NaN
# 2    2020-01-03  0.032805       NaN  0.034180  0.013435  0.193521       NaN
# 3    2020-01-04  0.035837       NaN  0.034595  0.013521  0.194355       NaN
# 4    2020-01-05  0.036459       NaN  0.034721  0.013623  0.195537       NaN
# ..          ...       ...       ...       ...       ...       ...       ...
# 360  2020-12-26  0.079030  5.182181  0.157824  0.027738  0.294713  0.037995
# 361  2020-12-27  0.080701  5.136191  0.154422  0.028846  0.283039  0.039308
# 362  2020-12-28  0.081185  6.588822  0.176735  0.029532  0.247958  0.038988
# 363  2020-12-29  0.079888  7.519257  0.192164  0.027690  0.220962  0.037236
# 364  2020-12-30  0.078118  7.254300  0.184040  0.026945  0.211828  0.036105
#
#       POLYGON       BITCOIN  RS BITCOIN
# 0    0.014962   7200.174316         NaN
# 1    0.014651   6985.470215   -0.029819
# 2    0.015194   7344.884277    0.051452
# 3    0.014961   7410.656738    0.008955
# 4    0.014914   7411.317383    0.000089
# ..        ...           ...         ...
# 360  0.019294  26437.037109    0.071853
# 361  0.018301  26272.294922   -0.006231
# 362  0.018873  27084.808594    0.030927
# 363  0.018449  27362.437500    0.010250
# 364  0.018135  28840.953125    0.054034
#
# [365 rows x 10 columns]

# %%
(dataset['RS BITCOIN'].mean() * 365) *100 #taxa de retorno anual com 365 dias em porcentagem
# Out:
# 87.22254675548268

# %%
dataset['RS BITCOIN'].mean() #média diária de retorno
# Out:
# 0.0023896588152187035

# %%
dataset['RS MANA'] = (dataset['MANA'] / dataset['MANA'].shift(1))-1
dataset['RS POLKADOT'] = (dataset['POLKADOT'] / dataset['POLKADOT'].shift(1))-1
dataset['RS CARDANO']=(dataset['CARDANO'] /dataset['CARDANO'].shift(1))-1
dataset['RS TRON']=(dataset['TRON'] /dataset['TRON'].shift(1))-1
dataset['RS RIPLE']=(dataset['RIPLE'] /dataset['RIPLE'].shift(1))-1
dataset['RS SAND']=(dataset['SAND'] /dataset['SAND'].shift(1))-1
dataset['RS BITCOIN']=(dataset['BITCOIN'] /dataset['BITCOIN'].shift(1))-1

# %%
dataset
# Out:
#            Date      MANA  POLKADOT   CARDANO      TRON     RIPLE      SAND  \
# 0    2020-01-01  0.031483       NaN  0.033458  0.013250  0.192667       NaN
# 1    2020-01-02  0.032639       NaN  0.032751  0.012870  0.188043       NaN
# 2    2020-01-03  0.032805       NaN  0.034180  0.013435  0.193521       NaN
# 3    2020-01-04  0.035837       NaN  0.034595  0.013521  0.194355       NaN
# 4    2020-01-05  0.036459       NaN  0.034721  0.013623  0.195537       NaN
# ..          ...       ...       ...       ...       ...       ...       ...
# 864  2022-05-14  1.326140       NaN  0.539358  0.072501  0.427774  1.432852
# 865  2022-05-15  1.330976       NaN  0.597500  0.072358  0.447371  1.448660
# 866  2022-05-16  1.172838       NaN  0.556716  0.069088  0.422499  1.314255
# 867  2022-05-17  1.213923       NaN  0.578077  0.072293  0.437623  1.371631
# 868  2022-05-18  1.039548  9.524648  0.506569  0.071071  0.406661  1.193646
#
#       POLYGON       BITCOIN  RS BITCOIN   RS MANA  RS POLKADOT  RS CARDANO  \
# 0    0.014962   7200.174316         NaN       NaN          NaN         NaN
# 1    0.014651   6985.470215   -0.029819  0.036718          NaN   -0.021131
# 2    0.015194   7344.884277    0.051452  0.005086          NaN    0.043632
# 3    0.014961   7410.656738    0.008955  0.092425          NaN    0.012142
# 4    0.014914   7411.317383    0.000089  0.017356          NaN    0.003642
# ..        ...           ...         ...       ...          ...         ...
# 864  0.686139  30101.265625    0.027940  0.311584          NaN    0.019817
# 865  0.737566  31305.113281    0.039993  0.003647          NaN    0.107799
# 866  0.677282  29862.917969   -0.046069 -0.118814          NaN   -0.068258
# 867  0.726942  30425.857422    0.018851  0.035030          NaN    0.038370
# 868  0.628314  28762.384766   -0.054673 -0.143646          NaN   -0.123699
#
#       RS TRON  RS RIPLE   RS SAND
# 0         NaN       NaN       NaN
# 1   -0.028679 -0.024000       NaN
# 2    0.043901  0.029132       NaN
# 3    0.006401  0.004310       NaN
# 4    0.007544  0.006082       NaN
# ..        ...       ...       ...
# 864 -0.022990  0.010290  0.129563
# 865 -0.001972  0.045812  0.011033
# 866 -0.045192 -0.055596 -0.092779
# 867  0.046390  0.035797  0.043657
# 868 -0.016899 -0.070750 -0.129761
#
# [869 rows x 16 columns]

# %%
(dataset['RS MANA'].mean() *365) *100 #calculo da taxa ANUAL de retorno simples das empresas
# Out:
# 289.3799822789001

# %%
(dataset['RS POLKADOT'].mean() *365) *100
# Out:
# 234.1629300030022

# %%
(dataset['RS CARDANO'].mean() *365) *100
# Out:
# 184.93806109366452

# %%
(dataset['RS TRON'].mean() *365) *100
# Out:
# 131.54545024685163

# %%
(dataset['RS RIPLE'].mean() *365) *100
# Out:
# 113.36168477792108

# %%
(dataset['RS SAND'].mean() *365) *100
# Out:
# 342.26130416036864

# %%
(dataset['RS BITCOIN'].mean() *365) *100
# Out:
# 87.22254675548268

# %%
len(dataset) #mostra a quantidade de registros existentes na planilha
# Out:
# 869

# %% [markdown]
# Taxa de retorno logarítimica

# %%
dataset['BITCOIN'][0], dataset['BITCOIN'] [len(dataset)-1] #primeiro registro e o ultimo
# Out:
# (7200.17431640625, 28762.384765625)

# %%
np.log(dataset['MANA'][len(dataset)-1]/ dataset['MANA'][0]) * 100
# Out:
# 349.7093657181455

# %%
np.log(dataset['POLKADOT'][len(dataset)-1]/ dataset['POLKADOT'][0]) * 100
# Out:
# nan

# %%
np.log(dataset['CARDANO'][len(dataset)-1]/ dataset['CARDANO'][0]) * 100
# Out:
# 271.73702024621485

# %%
np.log(dataset['TRON'][len(dataset)-1]/ dataset['TRON'][0]) * 100
# Out:
# 167.96859098485655

# %%
np.log(dataset['RIPLE'][len(dataset)-1]/ dataset['RIPLE'][0]) * 100
# Out:
# 74.70174546188261

# %%
np.log(dataset['SAND'][len(dataset)-1]/ dataset['SAND'][0]) * 100
# Out:
# nan

# %%
np.log(dataset['POLYGON'][len(dataset)-1]/ dataset['POLYGON'][0]) * 100
# Out:
# 373.7526902051454

# %%
np.log(dataset['BITCOIN'][len(dataset)-1]/ dataset['BITCOIN'][0]) * 100
# Out:
# 138.49632126022854

# %% [markdown]
# Retorno de carteira de ações

# %%
dataset=pd.read_csv('criptos.csv') #leitura do csv
dataset
# Out:
#            Date      MANA  POLKADOT   CARDANO      TRON     RIPLE      SAND  \
# 0    2020-01-01  0.031483       NaN  0.033458  0.013250  0.192667       NaN
# 1    2020-01-02  0.032639       NaN  0.032751  0.012870  0.188043       NaN
# 2    2020-01-03  0.032805       NaN  0.034180  0.013435  0.193521       NaN
# 3    2020-01-04  0.035837       NaN  0.034595  0.013521  0.194355       NaN
# 4    2020-01-05  0.036459       NaN  0.034721  0.013623  0.195537       NaN
# ..          ...       ...       ...       ...       ...       ...       ...
# 864  2022-05-14  1.326140       NaN  0.539358  0.072501  0.427774  1.432852
# 865  2022-05-15  1.330976       NaN  0.597500  0.072358  0.447371  1.448660
# 866  2022-05-16  1.172838       NaN  0.556716  0.069088  0.422499  1.314255
# 867  2022-05-17  1.213923       NaN  0.578077  0.072293  0.437623  1.371631
# 868  2022-05-18  1.039548  9.524648  0.506569  0.071071  0.406661  1.193646
#
#       POLYGON       BITCOIN
# 0    0.014962   7200.174316
# 1    0.014651   6985.470215
# 2    0.015194   7344.884277
# 3    0.014961   7410.656738
# 4    0.014914   7411.317383
# ..        ...           ...
# 864  0.686139  30101.265625
# 865  0.737566  31305.113281
# 866  0.677282  29862.917969
# 867  0.726942  30425.857422
# 868  0.628314  28762.384766
#
# [869 rows x 9 columns]

# %%
dataset_normalizado=dataset.copy()  #criei uma váriável que vai receber uma cópia do dataset
for i in dataset_normalizado.columns[1:]: #acessamos as colunas na posição 1 até a ultima coluna
    dataset_normalizado[i]=(dataset_normalizado[i]/dataset_normalizado[i][0])

# %%
dataset_normalizado #apresentando gráfico normalizado começando com o preço na posição 1
# Out:
#            Date       MANA  POLKADOT    CARDANO      TRON     RIPLE  SAND  \
# 0    2020-01-01   1.000000       NaN   1.000000  1.000000  1.000000   NaN
# 1    2020-01-02   1.036718       NaN   0.978869  0.971321  0.976000   NaN
# 2    2020-01-03   1.041991       NaN   1.021579  1.013962  1.004432   NaN
# 3    2020-01-04   1.138297       NaN   1.033983  1.020453  1.008761   NaN
# 4    2020-01-05   1.158054       NaN   1.037749  1.028151  1.014896   NaN
# ..          ...        ...       ...        ...       ...       ...   ...
# 864  2022-05-14  42.122419       NaN  16.120451  5.471773  2.220276   NaN
# 865  2022-05-15  42.276025       NaN  17.858212  5.460981  2.321991   NaN
# 866  2022-05-16  37.253058       NaN  16.639251  5.214189  2.192898   NaN
# 867  2022-05-17  38.558049       NaN  17.277693  5.456075  2.271396   NaN
# 868  2022-05-18  33.019347       NaN  15.140454  5.363871  2.110695   NaN
#
#        POLYGON   BITCOIN
# 0     1.000000  1.000000
# 1     0.979214  0.970181
# 2     1.015506  1.020098
# 3     0.999933  1.029233
# 4     0.996792  1.029325
# ..         ...       ...
# 864  45.858775  4.180630
# 865  49.295950  4.347827
# 866  45.266808  4.147527
# 867  48.585885  4.225711
# 868  41.994006  3.994679
#
# [869 rows x 9 columns]

# %%
dataset_normalizado.plot(x='Date',figsize=(15,7)); #gerando gráfico normalizado

# %%
dataset_normalizado.drop(labels=['Date'], axis=1, inplace=True) #apaga a coluna 1 que é a "Data" e inplace=True para fazer a alteração diretamente nessa base de dados.

# %%
#temos as respectivas taxas de retorno para cada uma das ações e não temos mais a coluna 'Data'.
retorno_carteira=(dataset_normalizado/dataset_normalizado.shift(1))-1
retorno_carteira.head()
# Out:
#        MANA  POLKADOT   CARDANO      TRON     RIPLE  SAND   POLYGON   BITCOIN
# 0       NaN       NaN       NaN       NaN       NaN   NaN       NaN       NaN
# 1  0.036718       NaN -0.021131 -0.028679 -0.024000   NaN -0.020786 -0.029819
# 2  0.005086       NaN  0.043632  0.043901  0.029132   NaN  0.037062  0.051452
# 3  0.092425       NaN  0.012142  0.006401  0.004310   NaN -0.015335  0.008955
# 4  0.017356       NaN  0.003642  0.007544  0.006082   NaN -0.003141  0.000089

# %%
retorno_anual=retorno_carteira.mean()*365 #calculo do retorno médio anual dessa carteira
retorno_anual
# Out:
# MANA        2.893800
# POLKADOT         NaN
# CARDANO     1.849381
# TRON        1.315455
# RIPLE       1.133617
# SAND             NaN
# POLYGON     2.810905
# BITCOIN     0.872225
# dtype: float64

# %%
retorno_anual=retorno_anual*100 #calculo do retorno anual de cada ação
retorno_anual
# Out:
# MANA        289.379982
# POLKADOT           NaN
# CARDANO     184.938061
# TRON        131.545450
# RIPLE       113.361685
# SAND               NaN
# POLYGON     281.090494
# BITCOIN      87.222547
# dtype: float64

# %%
#pesos_carteira1=np.array([0.25,0.25,0.25,0.25,0.0]) #declarando o peso de cada ação

# %%
#pesos_carteira1.sum() # Peso da carteira deve OBRIGATORIAMENTE fechar com o valor 1.0

# %%
#cálculo de retorno da carteira
#é feito a multiplicação do preço da ação em relação ao seu peso, e posteriormente é feito a soma.
#np.dot(retorno_anual, pesos_carteira1)

# %%
pesos_carteira2=np.array([28.59,20.82,19.43,9.51,8.38,6.64,6.63,0.0])

# %%
pesos_carteira2.sum()
# Out:
# 100.0

# %%
#cálculo de retorno da carteira
#é feito a multiplicação do preço da ação em relação ao seu peso, e posteriormente é feito a soma.
np.dot(retorno_anual,pesos_carteira2)
# Out:
# nan

# %% [markdown]
# Gráfico de Carteira X BOVA

# %%
dataset=pd.read_csv('criptos.csv')

# %%
dataset_normalizado = dataset.copy()
for i in dataset_normalizado.columns[1:]:
    dataset_normalizado [i]= (dataset_normalizado[i]/dataset_normalizado[i] [0])
dataset_normalizado.head()
# Out:
#          Date      MANA  POLKADOT   CARDANO      TRON     RIPLE  SAND  \
# 0  2020-01-01  1.000000       NaN  1.000000  1.000000  1.000000   NaN
# 1  2020-01-02  1.036718       NaN  0.978869  0.971321  0.976000   NaN
# 2  2020-01-03  1.041991       NaN  1.021579  1.013962  1.004432   NaN
# 3  2020-01-04  1.138297       NaN  1.033983  1.020453  1.008761   NaN
# 4  2020-01-05  1.158054       NaN  1.037749  1.028151  1.014896   NaN
#
#     POLYGON   BITCOIN
# 0  1.000000  1.000000
# 1  0.979214  0.970181
# 2  1.015506  1.020098
# 3  0.999933  1.029233
# 4  0.996792  1.029325

# %%
dataset_normalizado ['CARTEIRA']= (dataset_normalizado['MANA']+dataset_normalizado['POLKADOT']+dataset_normalizado['CARDANO']+dataset_normalizado['TRON']+dataset_normalizado['RIPLE']+dataset_normalizado['SAND']+dataset_normalizado['POLYGON']) / 7
dataset_normalizado
# Out:
#            Date       MANA  POLKADOT    CARDANO      TRON     RIPLE  SAND  \
# 0    2020-01-01   1.000000       NaN   1.000000  1.000000  1.000000   NaN
# 1    2020-01-02   1.036718       NaN   0.978869  0.971321  0.976000   NaN
# 2    2020-01-03   1.041991       NaN   1.021579  1.013962  1.004432   NaN
# 3    2020-01-04   1.138297       NaN   1.033983  1.020453  1.008761   NaN
# 4    2020-01-05   1.158054       NaN   1.037749  1.028151  1.014896   NaN
# ..          ...        ...       ...        ...       ...       ...   ...
# 864  2022-05-14  42.122419       NaN  16.120451  5.471773  2.220276   NaN
# 865  2022-05-15  42.276025       NaN  17.858212  5.460981  2.321991   NaN
# 866  2022-05-16  37.253058       NaN  16.639251  5.214189  2.192898   NaN
# 867  2022-05-17  38.558049       NaN  17.277693  5.456075  2.271396   NaN
# 868  2022-05-18  33.019347       NaN  15.140454  5.363871  2.110695   NaN
#
#        POLYGON   BITCOIN  CARTEIRA
# 0     1.000000  1.000000       NaN
# 1     0.979214  0.970181       NaN
# 2     1.015506  1.020098       NaN
# 3     0.999933  1.029233       NaN
# 4     0.996792  1.029325       NaN
# ..         ...       ...       ...
# 864  45.858775  4.180630       NaN
# 865  49.295950  4.347827       NaN
# 866  45.266808  4.147527       NaN
# 867  48.585885  4.225711       NaN
# 868  41.994006  3.994679       NaN
#
# [869 rows x 10 columns]

# %%
figura=px.line(title='Comparativo Carteira x Bitcoin')
for i in dataset_normalizado.columns[1:]:
    figura.add_scatter(x=dataset_normalizado['Date'], y=dataset_normalizado[i], name=i)
figura.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# g:\Meu Drive\Projetos Pessoais\Coincheck\2-Taxa de retorno Simples\Base de dados e Retorno- Taxas de Retorno.ipynb Cell 65' in <cell line: 4>()
#       <a href='vscode-notebook-cell:/g%3A/Meu%20Drive/Projetos%20Pessoais/Coincheck/2-Taxa%20de%20retorno%20Simples/Base%20de%20dados%20e%20Retorno-%20Taxas%20de%20Retorno.ipynb#ch0000064?line=1'>2</a> for i in dataset_normalizado.columns[1:]:
#       <a href='vscode-notebook-cell:/g%3A/Meu%20Drive/Projetos%20Pessoais/Coincheck/2-Taxa%20de%20retorno%20Simples/Base%20de%20dados%20e%20Retorno-%20Taxas%20de%20Retorno.ipynb#ch0000064?line=2'>3</a>     figura.add_scatter(x=dataset_normalizado['Date'], y=dataset_normalizado[i], name=i)
# ----> <a href='vscode-notebook-cell:/g%3A/Meu%20Drive/Projetos%20Pessoais/Coincheck/2-Taxa%20de%20retorno%20Simples/Base%20de%20dados%20e%20Retorno-%20Taxas%20de%20Retorno.ipynb#ch0000064?line=3'>4</a> figura.show()
#
# File c:\Users\Jeff Luis\AppData\Local\Programs\Python\Python310\lib\site-packages\plotly\basedatatypes.py:3400, in BaseFigure.show(self, *args, **kwargs)
#    <a href='file:///c%3A/Users/Jeff%20Luis/AppData/Local/Programs/Python/Python310/lib/site-packages/plotly/basedatatypes.py?line=3366'>3367</a> """
#    <a href='file:///c%3A/Users/Jeff%20Luis/AppData/Local/Programs/Python/Python310/lib/site-packages/plotly/basedatatypes.py?line=3367'>3368</a> Show a figure using either the default renderer(s) or the renderer(s)
#    <a href='file:///c%3A/Users/Jeff%20Luis/AppData/Local/Programs/Python/Python310/lib/site-packages/plotly/basedatatypes.py?line=3368'>3369</a> specified by the renderer argument
#    (...)
#    <a href='file:///c%3A/Users/Jeff%20Luis/AppData/Local/Programs/Python/Python310/lib/site-packages/plotly/basedatatypes.py?line=3395'>3396</a> None
#    <a href='file:///c%3A/Users/Jeff%20Luis/AppData/Local/Programs/Python/Python310/lib/site-packages/plotly/basedatatypes.py?line=3396'>3397</a> """
#    <a href='file:///c%3A/Users/Jeff%20Luis/AppData/Local/Programs/Python/Python310/lib/site-packages/plotly/basedatatypes.py?line=3397'>3398</a> import plotly.io as pio
# -> <a href='file:///c%3A/Users/Jeff%20Luis/AppData/Local/Programs/Python/Python310/lib/site-packages/plotly/basedatatypes.py?line=3399'>3400</a> return pio.show(self, *args, **kwargs)
#
# File c:\Users\Jeff Luis\AppData\Local\Programs\Python\Python310\lib\site-packages\plotly\io\_renderers.py:397, in show(fig, renderer, validate, **kwargs)
#     <a href='file:///c%3A/Users/Jeff%20Luis/AppData/Local/Programs/Python/Python310/lib/site-packages/plotly/io/_renderers.py?line=391'>392</a>         raise ValueError(
#     <a href='file:///c%3A/Users/Jeff%20Luis/AppData/Local/Programs/Python/Python310/lib/site-packages/plotly/io/_renderers.py?line=392'>393</a>             "Mime type rendering requires ipython but it is not installed"
#     <a href='file:///c%3A/Users/Jeff%20Luis/AppData/Local/Programs/Python/Python310/lib/site-packages/plotly/io/_renderers.py?line=393'>394</a>         )
#     <a href='file:///c%3A/Users/Jeff%20Luis/AppData/Local/Programs/Python/Python310/lib/site-packages/plotly/io/_renderers.py?line=395'>396</a>     if not nbformat or LooseVersion(nbformat.__version__) < LooseVersion("4.2.0"):
# --> <a href='file:///c%3A/Users/Jeff%20Luis/AppData/Local/Programs/Python/Python310/lib/site-packages/plotly/io/_renderers.py?line=396'>397</a>         raise ValueError(
#     <a href='file:///c%3A/Users/Jeff%20Luis/AppData/Local/Programs/Python/Python310/lib/site-packages/plotly/io/_renderers.py?line=397'>398</a>             "Mime type rendering requires nbformat>=4.2.0 but it is not installed"
#     <a href='file:///c%3A/Users/Jeff%20Luis/AppData/Local/Programs/Python/Python310/lib/site-packages/plotly/io/_renderers.py?line=398'>399</a>         )
#     <a href='file:///c%3A/Users/Jeff%20Luis/AppData/Local/Programs/Python/Python310/lib/site-packages/plotly/io/_renderers.py?line=400'>401</a>     ipython_display.display(bundle, raw=True)
#     <a href='file:///c%3A/Users/Jeff%20Luis/AppData/Local/Programs/Python/Python310/lib/site-packages/plotly/io/_renderers.py?line=402'>403</a> # external renderers
#
# ValueError: Mime type rendering requires nbformat>=4.2.0 but it is not installed
