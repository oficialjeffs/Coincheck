# %% [markdown]
# Importação das bibliotecas e base de dados

# %%
import pandas as pd
import numpy as np
import plotly.express as px

# %%
dataset = pd.read_csv('../1-Visualização de dados Financeiros/criptos.csv')

# %%
dataset.shape
# Out:
# (871, 9)

# %%
dataset
# Out:
#            Date      MANA  POLKADOT   CARDANO      TRON     RIPLE      SAND  \
# 0    2020-01-01  0.031483       NaN  0.033458  0.013250  0.192667       NaN
# 1    2020-01-02  0.032639       NaN  0.032751  0.012870  0.188043       NaN
# 2    2020-01-03  0.032805       NaN  0.034180  0.013435  0.193521       NaN
# 3    2020-01-04  0.035837       NaN  0.034595  0.013521  0.194355       NaN
# 4    2020-01-05  0.036459       NaN  0.034721  0.013623  0.195537       NaN
# ..          ...       ...       ...       ...       ...       ...       ...
# 866  2022-05-16  1.172838       NaN  0.556716  0.069088  0.422499  1.314255
# 867  2022-05-17  1.213923       NaN  0.578077  0.072293  0.437623  1.371631
# 868  2022-05-18  1.035926       NaN  0.505615  0.070974  0.406166  1.192518
# 869  2022-05-19  1.122525       NaN  0.533321  0.073608  0.419976  1.302092
# 870  2022-05-20  1.082942  9.699699  0.523556  0.073539  0.428881  1.267786
#
#       POLYGON       BITCOIN
# 0    0.014962   7200.174316
# 1    0.014651   6985.470215
# 2    0.015194   7344.884277
# 3    0.014961   7410.656738
# 4    0.014914   7411.317383
# ..        ...           ...
# 866  0.677282  29862.917969
# 867  0.726942  30425.857422
# 868  0.627577  28720.271484
# 869  0.658817  30314.333984
# 870  0.643836  29904.888672
#
# [871 rows x 9 columns]

# %% [markdown]
# Taxa de retorno simples

# %%
len(dataset)
# Out:
# 871

# %%
dataset['BITCOIN'][0], dataset['BITCOIN'][len(dataset)-1]
# Out:
# (7200.17431640625, 29904.888671875)

# %%
((dataset['MANA'][len(dataset)-1] - dataset['MANA'][0]) / dataset['MANA'][0])*100
# Out:
# 3339.767331155879

# %%
((dataset['POLKADOT'][len(dataset)-1] - dataset['POLKADOT'][0]) / dataset['POLKADOT'][0])*100
# Out:
# nan

# %%
((dataset['CARDANO'][len(dataset)-1] - dataset['CARDANO'][0]) / dataset['CARDANO'][0])*100
# Out:
# 1464.8144096525784

# %%
((dataset['TRON'][len(dataset)-1] - dataset['TRON'][0]) / dataset['TRON'][0])*100
# Out:
# 455.0120302277089

# %%
((dataset['RIPLE'][len(dataset)-1] - dataset['RIPLE'][0]) / dataset['RIPLE'][0])*100
# Out:
# 122.60238162414743

# %%
((dataset['SAND'][len(dataset)-1] - dataset['SAND'][0]) / dataset['SAND'][0])*100
# Out:
# nan

# %%
((dataset['BITCOIN'][len(dataset)-1] - dataset['BITCOIN'][0]) / dataset['BITCOIN'][0])*100
# Out:
# 315.3356204687156

# %%
(dataset['BITCOIN'][len(dataset)-1] / dataset['BITCOIN'][0]-1)*100 #maneira alternativa de fazer o mesmo cálculo
# Out:
# 315.33562046871555

# %%
dataset['BITCOIN']
# Out:
# 0       7200.174316
# 1       6985.470215
# 2       7344.884277
# 3       7410.656738
# 4       7411.317383
#            ...
# 866    29862.917969
# 867    30425.857422
# 868    28720.271484
# 869    30314.333984
# 870    29904.888672
# Name: BITCOIN, Length: 871, dtype: float64

# %%
dataset['BITCOIN'].shift(1) #O comando "shift" zera os valores sitados e desloca uma lista de númeor abaixo
# Out:
# 0               NaN
# 1       7200.174316
# 2       6985.470215
# 3       7344.884277
# 4       7410.656738
#            ...
# 866    31305.113281
# 867    29862.917969
# 868    30425.857422
# 869    28720.271484
# 870    30314.333984
# Name: BITCOIN, Length: 871, dtype: float64

# %%
dataset['RS BITCOIN']= (dataset['BITCOIN'] / dataset['BITCOIN'].shift(1))-1 #calculo da taxa DIÁRIA de retorno simples

# %%
dataset
# Out:
#            Date      MANA  POLKADOT   CARDANO      TRON     RIPLE      SAND  \
# 0    2020-01-01  0.031483       NaN  0.033458  0.013250  0.192667       NaN
# 1    2020-01-02  0.032639       NaN  0.032751  0.012870  0.188043       NaN
# 2    2020-01-03  0.032805       NaN  0.034180  0.013435  0.193521       NaN
# 3    2020-01-04  0.035837       NaN  0.034595  0.013521  0.194355       NaN
# 4    2020-01-05  0.036459       NaN  0.034721  0.013623  0.195537       NaN
# ..          ...       ...       ...       ...       ...       ...       ...
# 866  2022-05-16  1.172838       NaN  0.556716  0.069088  0.422499  1.314255
# 867  2022-05-17  1.213923       NaN  0.578077  0.072293  0.437623  1.371631
# 868  2022-05-18  1.035926       NaN  0.505615  0.070974  0.406166  1.192518
# 869  2022-05-19  1.122525       NaN  0.533321  0.073608  0.419976  1.302092
# 870  2022-05-20  1.082942  9.699699  0.523556  0.073539  0.428881  1.267786
#
#       POLYGON       BITCOIN  RS BITCOIN
# 0    0.014962   7200.174316         NaN
# 1    0.014651   6985.470215   -0.029819
# 2    0.015194   7344.884277    0.051452
# 3    0.014961   7410.656738    0.008955
# 4    0.014914   7411.317383    0.000089
# ..        ...           ...         ...
# 866  0.677282  29862.917969   -0.046069
# 867  0.726942  30425.857422    0.018851
# 868  0.627577  28720.271484   -0.056057
# 869  0.658817  30314.333984    0.055503
# 870  0.643836  29904.888672   -0.013507
#
# [871 rows x 10 columns]

# %%
dataset['RS BITCOIN'].plot(); #Gráfico de taxas de retorno diário

# %%
dataset['RS BITCOIN'].mean()
# Out:
# 0.002430846104426151

# %%
dataset.head(365) #busca os primeiros 365 registros
# Out:
#            Date      MANA  POLKADOT   CARDANO      TRON     RIPLE      SAND  \
# 0    2020-01-01  0.031483       NaN  0.033458  0.013250  0.192667       NaN
# 1    2020-01-02  0.032639       NaN  0.032751  0.012870  0.188043       NaN
# 2    2020-01-03  0.032805       NaN  0.034180  0.013435  0.193521       NaN
# 3    2020-01-04  0.035837       NaN  0.034595  0.013521  0.194355       NaN
# 4    2020-01-05  0.036459       NaN  0.034721  0.013623  0.195537       NaN
# ..          ...       ...       ...       ...       ...       ...       ...
# 360  2020-12-26  0.079030  5.182181  0.157824  0.027738  0.294713  0.037995
# 361  2020-12-27  0.080701  5.136191  0.154422  0.028846  0.283039  0.039308
# 362  2020-12-28  0.081185  6.588822  0.176735  0.029532  0.247958  0.038988
# 363  2020-12-29  0.079888  7.519257  0.192164  0.027690  0.220962  0.037236
# 364  2020-12-30  0.078118  7.254300  0.184040  0.026945  0.211828  0.036105
#
#       POLYGON       BITCOIN  RS BITCOIN
# 0    0.014962   7200.174316         NaN
# 1    0.014651   6985.470215   -0.029819
# 2    0.015194   7344.884277    0.051452
# 3    0.014961   7410.656738    0.008955
# 4    0.014914   7411.317383    0.000089
# ..        ...           ...         ...
# 360  0.019294  26437.037109    0.071853
# 361  0.018301  26272.294922   -0.006231
# 362  0.018873  27084.808594    0.030927
# 363  0.018449  27362.437500    0.010250
# 364  0.018135  28840.953125    0.054034
#
# [365 rows x 10 columns]

# %%
(dataset['RS BITCOIN'].mean() * 365) *100 #taxa de retorno anual com 365 dias em porcentagem
# Out:
# 88.7258828115545

# %%
dataset['RS BITCOIN'].mean() #média diária de retorno
# Out:
# 0.002430846104426151

# %%
dataset['RS MANA'] = (dataset['MANA'] / dataset['MANA'].shift(1))-1
dataset['RS POLKADOT'] = (dataset['POLKADOT'] / dataset['POLKADOT'].shift(1))-1
dataset['RS CARDANO']=(dataset['CARDANO'] /dataset['CARDANO'].shift(1))-1
dataset['RS TRON']=(dataset['TRON'] /dataset['TRON'].shift(1))-1
dataset['RS RIPLE']=(dataset['RIPLE'] /dataset['RIPLE'].shift(1))-1
dataset['RS SAND']=(dataset['SAND'] /dataset['SAND'].shift(1))-1
dataset['RS BITCOIN']=(dataset['BITCOIN'] /dataset['BITCOIN'].shift(1))-1

# %%
dataset
# Out:
#            Date      MANA  POLKADOT   CARDANO      TRON     RIPLE      SAND  \
# 0    2020-01-01  0.031483       NaN  0.033458  0.013250  0.192667       NaN
# 1    2020-01-02  0.032639       NaN  0.032751  0.012870  0.188043       NaN
# 2    2020-01-03  0.032805       NaN  0.034180  0.013435  0.193521       NaN
# 3    2020-01-04  0.035837       NaN  0.034595  0.013521  0.194355       NaN
# 4    2020-01-05  0.036459       NaN  0.034721  0.013623  0.195537       NaN
# ..          ...       ...       ...       ...       ...       ...       ...
# 866  2022-05-16  1.172838       NaN  0.556716  0.069088  0.422499  1.314255
# 867  2022-05-17  1.213923       NaN  0.578077  0.072293  0.437623  1.371631
# 868  2022-05-18  1.035926       NaN  0.505615  0.070974  0.406166  1.192518
# 869  2022-05-19  1.122525       NaN  0.533321  0.073608  0.419976  1.302092
# 870  2022-05-20  1.082942  9.699699  0.523556  0.073539  0.428881  1.267786
#
#       POLYGON       BITCOIN  RS BITCOIN   RS MANA  RS POLKADOT  RS CARDANO  \
# 0    0.014962   7200.174316         NaN       NaN          NaN         NaN
# 1    0.014651   6985.470215   -0.029819  0.036718          NaN   -0.021131
# 2    0.015194   7344.884277    0.051452  0.005086          NaN    0.043632
# 3    0.014961   7410.656738    0.008955  0.092425          NaN    0.012142
# 4    0.014914   7411.317383    0.000089  0.017356          NaN    0.003642
# ..        ...           ...         ...       ...          ...         ...
# 866  0.677282  29862.917969   -0.046069 -0.118814          NaN   -0.068258
# 867  0.726942  30425.857422    0.018851  0.035030          NaN    0.038370
# 868  0.627577  28720.271484   -0.056057 -0.146630          NaN   -0.125350
# 869  0.658817  30314.333984    0.055503  0.083596          NaN    0.054797
# 870  0.643836  29904.888672   -0.013507 -0.035263          NaN   -0.018311
#
#       RS TRON  RS RIPLE   RS SAND
# 0         NaN       NaN       NaN
# 1   -0.028679 -0.024000       NaN
# 2    0.043901  0.029132       NaN
# 3    0.006401  0.004310       NaN
# 4    0.007544  0.006082       NaN
# ..        ...       ...       ...
# 866 -0.045192 -0.055596 -0.092779
# 867  0.046390  0.035797  0.043657
# 868 -0.018245 -0.071882 -0.130584
# 869  0.037112  0.034001  0.091885
# 870 -0.000936  0.021204 -0.026347
#
# [871 rows x 16 columns]

# %%
(dataset['RS MANA'].mean() *365) *100 #calculo da taxa ANUAL de retorno simples das empresas
# Out:
# 290.61733191145487

# %%
(dataset['RS POLKADOT'].mean() *365) *100
# Out:
# 234.1629300030022

# %%
(dataset['RS CARDANO'].mean() *365) *100
# Out:
# 185.97439654197598

# %%
(dataset['RS TRON'].mean() *365) *100
# Out:
# 132.70431748375748

# %%
(dataset['RS RIPLE'].mean() *365) *100
# Out:
# 115.36967829316964

# %%
(dataset['RS SAND'].mean() *365) *100
# Out:
# 344.8662371558595

# %%
(dataset['RS BITCOIN'].mean() *365) *100
# Out:
# 88.7258828115545

# %%
len(dataset) #mostra a quantidade de registros existentes na planilha
# Out:
# 871

# %% [markdown]
# Taxa de retorno logarítimica

# %%
dataset['BITCOIN'][0], dataset['BITCOIN'] [len(dataset)-1] #primeiro registro e o ultimo
# Out:
# (7200.17431640625, 29904.888671875)

# %%
np.log(dataset['MANA'][len(dataset)-1]/ dataset['MANA'][0]) * 100
# Out:
# 353.798892580002

# %%
np.log(dataset['POLKADOT'][len(dataset)-1]/ dataset['POLKADOT'][0]) * 100
# Out:
# nan

# %%
np.log(dataset['CARDANO'][len(dataset)-1]/ dataset['CARDANO'][0]) * 100
# Out:
# 275.03523218726207

# %%
np.log(dataset['TRON'][len(dataset)-1]/ dataset['TRON'][0]) * 100
# Out:
# 171.38196036093822

# %%
np.log(dataset['RIPLE'][len(dataset)-1]/ dataset['RIPLE'][0]) * 100
# Out:
# 80.0216951916277

# %%
np.log(dataset['SAND'][len(dataset)-1]/ dataset['SAND'][0]) * 100
# Out:
# nan

# %%
np.log(dataset['POLYGON'][len(dataset)-1]/ dataset['POLYGON'][0]) * 100
# Out:
# 376.19311663559216

# %%
np.log(dataset['BITCOIN'][len(dataset)-1]/ dataset['BITCOIN'][0]) * 100
# Out:
# 142.39167314225415

# %% [markdown]
# Retorno de carteira de ações

# %%
dataset=pd.read_csv('criptos.csv') #leitura do csv
dataset
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# g:\Meu Drive\Projetos Pessoais\Coincheck\2-Taxa de retorno Simples\Base de dados e Retorno- Taxas de Retorno.ipynb Cell 47' in <cell line: 1>()
# ----> <a href='vscode-notebook-cell:/g%3A/Meu%20Drive/Projetos%20Pessoais/Coincheck/2-Taxa%20de%20retorno%20Simples/Base%20de%20dados%20e%20Retorno-%20Taxas%20de%20Retorno.ipynb#ch0000046?line=0'>1</a> dataset=pd.read_csv('criptos.csv') #leitura do csv
#       <a href='vscode-notebook-cell:/g%3A/Meu%20Drive/Projetos%20Pessoais/Coincheck/2-Taxa%20de%20retorno%20Simples/Base%20de%20dados%20e%20Retorno-%20Taxas%20de%20Retorno.ipynb#ch0000046?line=1'>2</a> dataset
#
# File c:\Users\Jeff Luis\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\util\_decorators.py:311, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     <a href='file:///c%3A/Users/Jeff%20Luis/AppData/Local/Programs/Python/Python310/lib/site-packages/pandas/util/_decorators.py?line=304'>305</a> if len(args) > num_allow_args:
#     <a href='file:///c%3A/Users/Jeff%20Luis/AppData/Local/Programs/Python/Python310/lib/site-packages/pandas/util/_decorators.py?line=305'>306</a>     warnings.warn(
#     <a href='file:///c%3A/Users/Jeff%20Luis/AppData/Local/Programs/Python/Python310/lib/site-packages/pandas/util/_decorators.py?line=306'>307</a>         msg.format(arguments=arguments),
#     <a href='file:///c%3A/Users/Jeff%20Luis/AppData/Local/Programs/Python/Python310/lib/site-packages/pandas/util/_decorators.py?line=307'>308</a>         FutureWarning,
#     <a href='file:///c%3A/Users/Jeff%20Luis/AppData/Local/Programs/Python/Python310/lib/site-packages/pandas/util/_decorators.py?line=308'>309</a>         stacklevel=stacklevel,
#     <a href='file:///c%3A/Users/Jeff%20Luis/AppData/Local/Programs/Python/Python310/lib/site-packages/pandas/util/_decorators.py?line=309'>310</a>     )
# --> <a href='file:///c%3A/Users/Jeff%20Luis/AppData/Local/Programs/Python/Python310/lib/site-packages/pandas/util/_decorators.py?line=310'>311</a> return func(*args, **kwargs)
#
# File c:\Users\Jeff Luis\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\io\parsers\readers.py:680, in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, squeeze, prefix, mangle_dupe_cols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, error_bad_lines, warn_bad_lines, on_bad_lines, delim_whitespace, low_memory, memory_map, float_precision, storage_options)
#     <a href='file:///c%3A/Users/Jeff%20Luis/AppData/Local/Programs/Python/Python310/lib/site-packages/pandas/io/parsers/readers.py?line=664'>665</a> kwds_defaults = _refine_defaults_read(
#     <a href='file:///c%3A/Users/Jeff%20Luis/AppData/Local/Programs/Python/Python310/lib/site-packages/pandas/io/parsers/readers.py?line=665'>666</a>     dialect,
#     <a href='file:///c%3A/Users/Jeff%20Luis/AppData/Local/Programs/Python/Python310/lib/site-packages/pandas/io/parsers/readers.py?line=666'>667</a>     delimiter,
#    (...)
#     <a href='file:///c%3A/Users/Jeff%20Luis/AppData/Local/Programs/Python/Python310/lib/site-packages/pandas/io/parsers/readers.py?line=675'>676</a>     defaults={"delimiter": ","},
#     <a href='file:///c%3A/Users/Jeff%20Luis/AppData/Local/Programs/Python/Python310/lib/site-packages/pandas/io/parsers/readers.py?line=676'>677</a> )
#     <a href='file:///c%3A/Users/Jeff%20Luis/AppData/Local/Programs/Python/Python310/lib/site-packages/pandas/io/parsers/readers.py?line=677'>678</a> kwds.update(kwds_defaults)
# --> <a href='file:///c%3A/Users/Jeff%20Luis/AppData/Local/Programs/Python/Python310/lib/site-packages/pandas/io/parsers/readers.py?line=679'>680</a> return _read(filepath_or_buffer, kwds)
#
# File c:\Users\Jeff Luis\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\io\parsers\readers.py:575, in _read(filepath_or_buffer, kwds)
#     <a href='file:///c%3A/Users/Jeff%20Luis/AppData/Local/Programs/Python/Python310/lib/site-packages/pandas/io/parsers/readers.py?line=571'>572</a> _validate_names(kwds.get("names", None))
#     <a href='file:///c%3A/Users/Jeff%20Luis/AppData/Local/Programs/Python/Python310/lib/site-packages/pandas/io/parsers/readers.py?line=573'>574</a> # Create the parser.
# --> <a href='file:///c%3A/Users/Jeff%20Luis/AppData/Local/Programs/Python/Python310/lib/site-packages/pandas/io/parsers/readers.py?line=574'>575</a> parser = TextFileReader(filepath_or_buffer, **kwds)
#     <a href='file:///c%3A/Users/Jeff%20Luis/AppData/Local/Programs/Python/Python310/lib/site-packages/pandas/io/parsers/readers.py?line=576'>577</a> if chunksize or iterator:
#     <a href='file:///c%3A/Users/Jeff%20Luis/AppData/Local/Programs/Python/Python310/lib/site-packages/pandas/io/parsers/readers.py?line=577'>578</a>     return parser
#
# File c:\Users\Jeff Luis\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\io\parsers\readers.py:933, in TextFileReader.__init__(self, f, engine, **kwds)
#     <a href='file:///c%3A/Users/Jeff%20Luis/AppData/Local/Programs/Python/Python310/lib/site-packages/pandas/io/parsers/readers.py?line=929'>930</a>     self.options["has_index_names"] = kwds["has_index_names"]
#     <a href='file:///c%3A/Users/Jeff%20Luis/AppData/Local/Programs/Python/Python310/lib/site-packages/pandas/io/parsers/readers.py?line=931'>932</a> self.handles: IOHandles | None = None
# --> <a href='file:///c%3A/Users/Jeff%20Luis/AppData/Local/Programs/Python/Python310/lib/site-packages/pandas/io/parsers/readers.py?line=932'>933</a> self._engine = self._make_engine(f, self.engine)
#
# File c:\Users\Jeff Luis\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\io\parsers\readers.py:1217, in TextFileReader._make_engine(self, f, engine)
#    <a href='file:///c%3A/Users/Jeff%20Luis/AppData/Local/Programs/Python/Python310/lib/site-packages/pandas/io/parsers/readers.py?line=1212'>1213</a>     mode = "rb"
#    <a href='file:///c%3A/Users/Jeff%20Luis/AppData/Local/Programs/Python/Python310/lib/site-packages/pandas/io/parsers/readers.py?line=1213'>1214</a> # error: No overload variant of "get_handle" matches argument types
#    <a href='file:///c%3A/Users/Jeff%20Luis/AppData/Local/Programs/Python/Python310/lib/site-packages/pandas/io/parsers/readers.py?line=1214'>1215</a> # "Union[str, PathLike[str], ReadCsvBuffer[bytes], ReadCsvBuffer[str]]"
#    <a href='file:///c%3A/Users/Jeff%20Luis/AppData/Local/Programs/Python/Python310/lib/site-packages/pandas/io/parsers/readers.py?line=1215'>1216</a> # , "str", "bool", "Any", "Any", "Any", "Any", "Any"
# -> <a href='file:///c%3A/Users/Jeff%20Luis/AppData/Local/Programs/Python/Python310/lib/site-packages/pandas/io/parsers/readers.py?line=1216'>1217</a> self.handles = get_handle(  # type: ignore[call-overload]
#    <a href='file:///c%3A/Users/Jeff%20Luis/AppData/Local/Programs/Python/Python310/lib/site-packages/pandas/io/parsers/readers.py?line=1217'>1218</a>     f,
#    <a href='file:///c%3A/Users/Jeff%20Luis/AppData/Local/Programs/Python/Python310/lib/site-packages/pandas/io/parsers/readers.py?line=1218'>1219</a>     mode,
#    <a href='file:///c%3A/Users/Jeff%20Luis/AppData/Local/Programs/Python/Python310/lib/site-packages/pandas/io/parsers/readers.py?line=1219'>1220</a>     encoding=self.options.get("encoding", None),
#    <a href='file:///c%3A/Users/Jeff%20Luis/AppData/Local/Programs/Python/Python310/lib/site-packages/pandas/io/parsers/readers.py?line=1220'>1221</a>     compression=self.options.get("compression", None),
#    <a href='file:///c%3A/Users/Jeff%20Luis/AppData/Local/Programs/Python/Python310/lib/site-packages/pandas/io/parsers/readers.py?line=1221'>1222</a>     memory_map=self.options.get("memory_map", False),
#    <a href='file:///c%3A/Users/Jeff%20Luis/AppData/Local/Programs/Python/Python310/lib/site-packages/pandas/io/parsers/readers.py?line=1222'>1223</a>     is_text=is_text,
#    <a href='file:///c%3A/Users/Jeff%20Luis/AppData/Local/Programs/Python/Python310/lib/site-packages/pandas/io/parsers/readers.py?line=1223'>1224</a>     errors=self.options.get("encoding_errors", "strict"),
#    <a href='file:///c%3A/Users/Jeff%20Luis/AppData/Local/Programs/Python/Python310/lib/site-packages/pandas/io/parsers/readers.py?line=1224'>1225</a>     storage_options=self.options.get("storage_options", None),
#    <a href='file:///c%3A/Users/Jeff%20Luis/AppData/Local/Programs/Python/Python310/lib/site-packages/pandas/io/parsers/readers.py?line=1225'>1226</a> )
#    <a href='file:///c%3A/Users/Jeff%20Luis/AppData/Local/Programs/Python/Python310/lib/site-packages/pandas/io/parsers/readers.py?line=1226'>1227</a> assert self.handles is not None
#    <a href='file:///c%3A/Users/Jeff%20Luis/AppData/Local/Programs/Python/Python310/lib/site-packages/pandas/io/parsers/readers.py?line=1227'>1228</a> f = self.handles.handle
#
# File c:\Users\Jeff Luis\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\io\common.py:789, in get_handle(path_or_buf, mode, encoding, compression, memory_map, is_text, errors, storage_options)
#     <a href='file:///c%3A/Users/Jeff%20Luis/AppData/Local/Programs/Python/Python310/lib/site-packages/pandas/io/common.py?line=783'>784</a> elif isinstance(handle, str):
#     <a href='file:///c%3A/Users/Jeff%20Luis/AppData/Local/Programs/Python/Python310/lib/site-packages/pandas/io/common.py?line=784'>785</a>     # Check whether the filename is to be opened in binary mode.
#     <a href='file:///c%3A/Users/Jeff%20Luis/AppData/Local/Programs/Python/Python310/lib/site-packages/pandas/io/common.py?line=785'>786</a>     # Binary mode does not support 'encoding' and 'newline'.
#     <a href='file:///c%3A/Users/Jeff%20Luis/AppData/Local/Programs/Python/Python310/lib/site-packages/pandas/io/common.py?line=786'>787</a>     if ioargs.encoding and "b" not in ioargs.mode:
#     <a href='file:///c%3A/Users/Jeff%20Luis/AppData/Local/Programs/Python/Python310/lib/site-packages/pandas/io/common.py?line=787'>788</a>         # Encoding
# --> <a href='file:///c%3A/Users/Jeff%20Luis/AppData/Local/Programs/Python/Python310/lib/site-packages/pandas/io/common.py?line=788'>789</a>         handle = open(
#     <a href='file:///c%3A/Users/Jeff%20Luis/AppData/Local/Programs/Python/Python310/lib/site-packages/pandas/io/common.py?line=789'>790</a>             handle,
#     <a href='file:///c%3A/Users/Jeff%20Luis/AppData/Local/Programs/Python/Python310/lib/site-packages/pandas/io/common.py?line=790'>791</a>             ioargs.mode,
#     <a href='file:///c%3A/Users/Jeff%20Luis/AppData/Local/Programs/Python/Python310/lib/site-packages/pandas/io/common.py?line=791'>792</a>             encoding=ioargs.encoding,
#     <a href='file:///c%3A/Users/Jeff%20Luis/AppData/Local/Programs/Python/Python310/lib/site-packages/pandas/io/common.py?line=792'>793</a>             errors=errors,
#     <a href='file:///c%3A/Users/Jeff%20Luis/AppData/Local/Programs/Python/Python310/lib/site-packages/pandas/io/common.py?line=793'>794</a>             newline="",
#     <a href='file:///c%3A/Users/Jeff%20Luis/AppData/Local/Programs/Python/Python310/lib/site-packages/pandas/io/common.py?line=794'>795</a>         )
#     <a href='file:///c%3A/Users/Jeff%20Luis/AppData/Local/Programs/Python/Python310/lib/site-packages/pandas/io/common.py?line=795'>796</a>     else:
#     <a href='file:///c%3A/Users/Jeff%20Luis/AppData/Local/Programs/Python/Python310/lib/site-packages/pandas/io/common.py?line=796'>797</a>         # Binary mode
#     <a href='file:///c%3A/Users/Jeff%20Luis/AppData/Local/Programs/Python/Python310/lib/site-packages/pandas/io/common.py?line=797'>798</a>         handle = open(handle, ioargs.mode)
#
# FileNotFoundError: [Errno 2] No such file or directory: 'criptos.csv'

# %%
dataset_normalizado=dataset.copy()  #criei uma váriável que vai receber uma cópia do dataset
for i in dataset_normalizado.columns[1:]: #acessamos as colunas na posição 1 até a ultima coluna
    dataset_normalizado[i]=(dataset_normalizado[i]/dataset_normalizado[i][0])

# %%
dataset_normalizado #apresentando gráfico normalizado começando com o preço na posição 1
# Out:
#            Date       MANA  POLKADOT    CARDANO      TRON     RIPLE  SAND  \
# 0    2020-01-01   1.000000       NaN   1.000000  1.000000  1.000000   NaN
# 1    2020-01-02   1.036718       NaN   0.978869  0.971321  0.976000   NaN
# 2    2020-01-03   1.041991       NaN   1.021579  1.013962  1.004432   NaN
# 3    2020-01-04   1.138297       NaN   1.033983  1.020453  1.008761   NaN
# 4    2020-01-05   1.158054       NaN   1.037749  1.028151  1.014896   NaN
# ..          ...        ...       ...        ...       ...       ...   ...
# 864  2022-05-14  42.122419       NaN  16.120451  5.471773  2.220276   NaN
# 865  2022-05-15  42.276025       NaN  17.858212  5.460981  2.321991   NaN
# 866  2022-05-16  37.253058       NaN  16.639251  5.214189  2.192898   NaN
# 867  2022-05-17  38.558049       NaN  17.277693  5.456075  2.271396   NaN
# 868  2022-05-18  33.019347       NaN  15.140454  5.363871  2.110695   NaN
#
#        POLYGON   BITCOIN
# 0     1.000000  1.000000
# 1     0.979214  0.970181
# 2     1.015506  1.020098
# 3     0.999933  1.029233
# 4     0.996792  1.029325
# ..         ...       ...
# 864  45.858775  4.180630
# 865  49.295950  4.347827
# 866  45.266808  4.147527
# 867  48.585885  4.225711
# 868  41.994006  3.994679
#
# [869 rows x 9 columns]

# %%
dataset_normalizado.plot(x='Date',figsize=(15,7)); #gerando gráfico normalizado

# %%
dataset_normalizado.drop(labels=['Date'], axis=1, inplace=True) #apaga a coluna 1 que é a "Data" e inplace=True para fazer a alteração diretamente nessa base de dados.

# %%
#temos as respectivas taxas de retorno para cada uma das ações e não temos mais a coluna 'Data'.
retorno_carteira=(dataset_normalizado/dataset_normalizado.shift(1))-1
retorno_carteira.head()
# Out:
#        MANA  POLKADOT   CARDANO      TRON     RIPLE  SAND   POLYGON   BITCOIN
# 0       NaN       NaN       NaN       NaN       NaN   NaN       NaN       NaN
# 1  0.036718       NaN -0.021131 -0.028679 -0.024000   NaN -0.020786 -0.029819
# 2  0.005086       NaN  0.043632  0.043901  0.029132   NaN  0.037062  0.051452
# 3  0.092425       NaN  0.012142  0.006401  0.004310   NaN -0.015335  0.008955
# 4  0.017356       NaN  0.003642  0.007544  0.006082   NaN -0.003141  0.000089

# %%
retorno_anual=retorno_carteira.mean()*365 #calculo do retorno médio anual dessa carteira
retorno_anual
# Out:
# MANA        2.893800
# POLKADOT         NaN
# CARDANO     1.849381
# TRON        1.315455
# RIPLE       1.133617
# SAND             NaN
# POLYGON     2.810905
# BITCOIN     0.872225
# dtype: float64

# %%
retorno_anual=retorno_anual*100 #calculo do retorno anual de cada ação
retorno_anual
# Out:
# MANA        289.379982
# POLKADOT           NaN
# CARDANO     184.938061
# TRON        131.545450
# RIPLE       113.361685
# SAND               NaN
# POLYGON     281.090494
# BITCOIN      87.222547
# dtype: float64

# %%
#pesos_carteira1=np.array([0.25,0.25,0.25,0.25,0.0]) #declarando o peso de cada ação

# %%
#pesos_carteira1.sum() # Peso da carteira deve OBRIGATORIAMENTE fechar com o valor 1.0

# %%
#cálculo de retorno da carteira
#é feito a multiplicação do preço da ação em relação ao seu peso, e posteriormente é feito a soma.
#np.dot(retorno_anual, pesos_carteira1)

# %%
pesos_carteira2=np.array([28.59,20.82,19.43,9.51,8.38,6.64,6.63,0.0])

# %%
pesos_carteira2.sum()
# Out:
# 100.0

# %%
#cálculo de retorno da carteira
#é feito a multiplicação do preço da ação em relação ao seu peso, e posteriormente é feito a soma.
np.dot(retorno_anual,pesos_carteira2)
# Out:
# nan

# %% [markdown]
# Gráfico de Carteira X BOVA

# %%
dataset=pd.read_csv('criptos.csv')

# %%
dataset_normalizado = dataset.copy()
for i in dataset_normalizado.columns[1:]:
    dataset_normalizado [i]= (dataset_normalizado[i]/dataset_normalizado[i] [0])
dataset_normalizado.head()
# Out:
#          Date      MANA  POLKADOT   CARDANO      TRON     RIPLE  SAND  \
# 0  2020-01-01  1.000000       NaN  1.000000  1.000000  1.000000   NaN
# 1  2020-01-02  1.036718       NaN  0.978869  0.971321  0.976000   NaN
# 2  2020-01-03  1.041991       NaN  1.021579  1.013962  1.004432   NaN
# 3  2020-01-04  1.138297       NaN  1.033983  1.020453  1.008761   NaN
# 4  2020-01-05  1.158054       NaN  1.037749  1.028151  1.014896   NaN
#
#     POLYGON   BITCOIN
# 0  1.000000  1.000000
# 1  0.979214  0.970181
# 2  1.015506  1.020098
# 3  0.999933  1.029233
# 4  0.996792  1.029325

# %%
dataset_normalizado ['CARTEIRA']= (dataset_normalizado['MANA']+dataset_normalizado['POLKADOT']+dataset_normalizado['CARDANO']+dataset_normalizado['TRON']+dataset_normalizado['RIPLE']+dataset_normalizado['SAND']+dataset_normalizado['POLYGON']) / 7
dataset_normalizado
# Out:
#            Date       MANA  POLKADOT    CARDANO      TRON     RIPLE  SAND  \
# 0    2020-01-01   1.000000       NaN   1.000000  1.000000  1.000000   NaN
# 1    2020-01-02   1.036718       NaN   0.978869  0.971321  0.976000   NaN
# 2    2020-01-03   1.041991       NaN   1.021579  1.013962  1.004432   NaN
# 3    2020-01-04   1.138297       NaN   1.033983  1.020453  1.008761   NaN
# 4    2020-01-05   1.158054       NaN   1.037749  1.028151  1.014896   NaN
# ..          ...        ...       ...        ...       ...       ...   ...
# 864  2022-05-14  42.122419       NaN  16.120451  5.471773  2.220276   NaN
# 865  2022-05-15  42.276025       NaN  17.858212  5.460981  2.321991   NaN
# 866  2022-05-16  37.253058       NaN  16.639251  5.214189  2.192898   NaN
# 867  2022-05-17  38.558049       NaN  17.277693  5.456075  2.271396   NaN
# 868  2022-05-18  33.019347       NaN  15.140454  5.363871  2.110695   NaN
#
#        POLYGON   BITCOIN  CARTEIRA
# 0     1.000000  1.000000       NaN
# 1     0.979214  0.970181       NaN
# 2     1.015506  1.020098       NaN
# 3     0.999933  1.029233       NaN
# 4     0.996792  1.029325       NaN
# ..         ...       ...       ...
# 864  45.858775  4.180630       NaN
# 865  49.295950  4.347827       NaN
# 866  45.266808  4.147527       NaN
# 867  48.585885  4.225711       NaN
# 868  41.994006  3.994679       NaN
#
# [869 rows x 10 columns]

# %%
figura=px.line(title='Comparativo Carteira x Bitcoin')
for i in dataset_normalizado.columns[1:]:
    figura.add_scatter(x=dataset_normalizado['Date'], y=dataset_normalizado[i], name=i)
figura.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# g:\Meu Drive\Projetos Pessoais\Coincheck\2-Taxa de retorno Simples\Base de dados e Retorno- Taxas de Retorno.ipynb Cell 65' in <cell line: 4>()
#       <a href='vscode-notebook-cell:/g%3A/Meu%20Drive/Projetos%20Pessoais/Coincheck/2-Taxa%20de%20retorno%20Simples/Base%20de%20dados%20e%20Retorno-%20Taxas%20de%20Retorno.ipynb#ch0000064?line=1'>2</a> for i in dataset_normalizado.columns[1:]:
#       <a href='vscode-notebook-cell:/g%3A/Meu%20Drive/Projetos%20Pessoais/Coincheck/2-Taxa%20de%20retorno%20Simples/Base%20de%20dados%20e%20Retorno-%20Taxas%20de%20Retorno.ipynb#ch0000064?line=2'>3</a>     figura.add_scatter(x=dataset_normalizado['Date'], y=dataset_normalizado[i], name=i)
# ----> <a href='vscode-notebook-cell:/g%3A/Meu%20Drive/Projetos%20Pessoais/Coincheck/2-Taxa%20de%20retorno%20Simples/Base%20de%20dados%20e%20Retorno-%20Taxas%20de%20Retorno.ipynb#ch0000064?line=3'>4</a> figura.show()
#
# File c:\Users\Jeff Luis\AppData\Local\Programs\Python\Python310\lib\site-packages\plotly\basedatatypes.py:3400, in BaseFigure.show(self, *args, **kwargs)
#    <a href='file:///c%3A/Users/Jeff%20Luis/AppData/Local/Programs/Python/Python310/lib/site-packages/plotly/basedatatypes.py?line=3366'>3367</a> """
#    <a href='file:///c%3A/Users/Jeff%20Luis/AppData/Local/Programs/Python/Python310/lib/site-packages/plotly/basedatatypes.py?line=3367'>3368</a> Show a figure using either the default renderer(s) or the renderer(s)
#    <a href='file:///c%3A/Users/Jeff%20Luis/AppData/Local/Programs/Python/Python310/lib/site-packages/plotly/basedatatypes.py?line=3368'>3369</a> specified by the renderer argument
#    (...)
#    <a href='file:///c%3A/Users/Jeff%20Luis/AppData/Local/Programs/Python/Python310/lib/site-packages/plotly/basedatatypes.py?line=3395'>3396</a> None
#    <a href='file:///c%3A/Users/Jeff%20Luis/AppData/Local/Programs/Python/Python310/lib/site-packages/plotly/basedatatypes.py?line=3396'>3397</a> """
#    <a href='file:///c%3A/Users/Jeff%20Luis/AppData/Local/Programs/Python/Python310/lib/site-packages/plotly/basedatatypes.py?line=3397'>3398</a> import plotly.io as pio
# -> <a href='file:///c%3A/Users/Jeff%20Luis/AppData/Local/Programs/Python/Python310/lib/site-packages/plotly/basedatatypes.py?line=3399'>3400</a> return pio.show(self, *args, **kwargs)
#
# File c:\Users\Jeff Luis\AppData\Local\Programs\Python\Python310\lib\site-packages\plotly\io\_renderers.py:397, in show(fig, renderer, validate, **kwargs)
#     <a href='file:///c%3A/Users/Jeff%20Luis/AppData/Local/Programs/Python/Python310/lib/site-packages/plotly/io/_renderers.py?line=391'>392</a>         raise ValueError(
#     <a href='file:///c%3A/Users/Jeff%20Luis/AppData/Local/Programs/Python/Python310/lib/site-packages/plotly/io/_renderers.py?line=392'>393</a>             "Mime type rendering requires ipython but it is not installed"
#     <a href='file:///c%3A/Users/Jeff%20Luis/AppData/Local/Programs/Python/Python310/lib/site-packages/plotly/io/_renderers.py?line=393'>394</a>         )
#     <a href='file:///c%3A/Users/Jeff%20Luis/AppData/Local/Programs/Python/Python310/lib/site-packages/plotly/io/_renderers.py?line=395'>396</a>     if not nbformat or LooseVersion(nbformat.__version__) < LooseVersion("4.2.0"):
# --> <a href='file:///c%3A/Users/Jeff%20Luis/AppData/Local/Programs/Python/Python310/lib/site-packages/plotly/io/_renderers.py?line=396'>397</a>         raise ValueError(
#     <a href='file:///c%3A/Users/Jeff%20Luis/AppData/Local/Programs/Python/Python310/lib/site-packages/plotly/io/_renderers.py?line=397'>398</a>             "Mime type rendering requires nbformat>=4.2.0 but it is not installed"
#     <a href='file:///c%3A/Users/Jeff%20Luis/AppData/Local/Programs/Python/Python310/lib/site-packages/plotly/io/_renderers.py?line=398'>399</a>         )
#     <a href='file:///c%3A/Users/Jeff%20Luis/AppData/Local/Programs/Python/Python310/lib/site-packages/plotly/io/_renderers.py?line=400'>401</a>     ipython_display.display(bundle, raw=True)
#     <a href='file:///c%3A/Users/Jeff%20Luis/AppData/Local/Programs/Python/Python310/lib/site-packages/plotly/io/_renderers.py?line=402'>403</a> # external renderers
#
# ValueError: Mime type rendering requires nbformat>=4.2.0 but it is not installed
